# %% [markdown]
# <a href="https://colab.research.google.com/github/DarshanSuresh/Data-Mining/blob/main/LAB_01_23_January_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LAB 01 - 23 January 2024

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# ## Importing Packages

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Reading Excel

# %%
df = pd.read_excel('age.xlsx')
print(df)
# Out:
#     age
# 0    33
# 1    33
# 2    13
# 3    15
# 4    35
# 5    35
# 6    35
# 7    35
# 8    16
# 9    16
# 10   19
# 11   20
# 12   20
# 13   36
# 14   40
# 15   41
# 16   22
# 17   22
# 18   45
# 19   46
# 20   25
# 21   25
# 22   25
# 23   25
# 24   52
# 25   70
# 26   30

# %% [markdown]
# ## Describing

# %%
df.describe()
# Out:
#              age
# count  27.000000
# mean   30.703704
# std    12.981688
# min    13.000000
# 25%    21.000000
# 50%    30.000000
# 75%    35.500000
# max    70.000000

# %% [markdown]
# ## Displaying

# %%
df.head()
# Out:
#    age
# 0   33
# 1   33
# 2   13
# 3   15
# 4   35
